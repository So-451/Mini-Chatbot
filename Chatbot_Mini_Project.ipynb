# %%
#1 Mounting the Google Drive

from google.colab import drive
drive.mount('/content/drive')
data_root='/content/drive/My Drive/ChatBot'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow==2.8
# Out:
# Requirement already satisfied: tensorflow==2.8 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.62.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)

# %%
#2 Importing Relevant Libraries

import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout
import nltk
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#3 Loading the Dataset: intents.json

data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'context': ' ',
#    'patterns': ['Hello', 'Hi there', 'Good morning', "What's up"],
#    'responses': ['Hey!', 'Hello', 'Hi!', 'Good morning!'],
#    'tag': 'hello'},
#   {'context': [' '],
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'tag': 'noanswer'},
#   {'context': ' ',
#    'patterns': ['What is your job', 'What is your work'],
#    'responses': ['My job is to make you feel like everything is okay.',
#     'I work to serve you as well as possible'],
#    'tag': 'job'},
#   {'context': ' ',
#    'patterns': ['What is your age', 'How old are you', 'When were you born'],
#    'responses': ['I was born in 2021'],
#    'tag': 'age'},
#   {'context': ' ',
#    'patterns': ['How are you today', 'How are you'],
#    'responses': ['I am feeling good, you?',
#     'Very good and you?',
#     "Actually, I'm okay and you?"],
#    'tag': 'feeling'},
#   {'context': 'feeling',
#    'patterns': ['I am good too',
#     'I feel fine',
#     'Good !',
#     'Fine',
#     'I am good',
#     'I am great',
#     'great'],
#    'responses': ['That is perfect!', "So, everything's okay!"],
#    'tag': 'good'},
#   {'context': 'feeling',
#    'patterns': ['I am feeling bad', 'No I am sad', 'No'],
#    'responses': ['I hope you will feel better !'],
#    'tag': 'bad'},
#   {'context': ' ',
#    'patterns': ['What can you do', 'What can I ask you', 'Can you help me'],
#    'responses': ['I can do a lot of things but here are some of my skills, you can ask me: the capital of a country, its currency and its area. A random number. To calculate a math operation.'],
#    'tag': 'actions'},
#   {'context': ' ',
#    'patterns': ['Are you a girl', 'You are a women'],
#    'responses': ["I don't incline to any gender"],
#    'tag': 'women'},
#   {'context': ' ',
#    'patterns': ['Are you a men', 'Are you a boy'],
#    'responses': ["I don't incline to any gender"],
#    'tag': 'men'},
#   {'context': ' ',
#    'patterns': ['Thank you', 'Thank you very much', 'thanks'],
#    'responses': ['I only do my job️', 'No problem!'],
#    'tag': 'thanks'},
#   {'context': ' ',
#    'patterns': ['Goodbye', 'Good afternoon', 'Bye'],
#    'responses': ['Goodbye!', 'See you soon!'],
#    'tag': 'goodbye'},
#   {'context': ' ',
#    'patterns': ['Where do you live'],
#    'responses': ['I live in a server located in the US!'],
#    'tag': 'city'},
#   {'context': ' ',
#    'patterns': ['What are you doing'],
#    'responses': ["Actually, I'm chatting with somebody"],
#    'tag': 'action'},
#   {'context': ' ',
#    'patterns': ['Can you wait 2 minutes', 'Please wait', 'Wait 2 secs please'],
#    'responses': ['Sure! I wait.'],
#    'tag': 'wait'},
#   {'context': ' ',
#    'patterns': ['Are you still there?', 'Are you here?'],
#    'responses': ['Of course! Always at your service.'],
#    'tag': 'still there'}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow  model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X
# Iterating over all the intents

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern
        words.extend(tokens) #and append tokens to words
        data_X.append(pattern) #appending pattern to data_X
        data_y.append(intent["tag"]) ,# appending the associated tag to each pattern

    # adding the tag to the classes if it's not there already
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# 5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7552
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 16,848
# Trainable params: 16,848
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 7ms/step - loss: 2.8291 - accuracy: 0.0244
# Epoch 2/150
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7123 - accuracy: 0.0732
# Epoch 3/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5229 - accuracy: 0.3171
# Epoch 4/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.4742 - accuracy: 0.2439
# Epoch 5/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.2125 - accuracy: 0.2927
# Epoch 6/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1672 - accuracy: 0.2683
# Epoch 7/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9623 - accuracy: 0.3659
# Epoch 8/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8683 - accuracy: 0.4390
# Epoch 9/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7782 - accuracy: 0.5122
# Epoch 10/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6592 - accuracy: 0.4878
# Epoch 11/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3690 - accuracy: 0.5610
# Epoch 12/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2976 - accuracy: 0.6341
# Epoch 13/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3694 - accuracy: 0.5366
# Epoch 14/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0105 - accuracy: 0.6829
# Epoch 15/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0751 - accuracy: 0.7317
# Epoch 16/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0307 - accuracy: 0.7073
# Epoch 17/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5614 - accuracy: 0.9024
# Epoch 18/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7249 - accuracy: 0.8049
# Epoch 19/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7669 - accuracy: 0.7561
# Epoch 20/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6928 - accuracy: 0.8049
# Epoch 21/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6229 - accuracy: 0.8293
# Epoch 22/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6731 - accuracy: 0.7561
# Epoch 23/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.8049
# Epoch 24/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7179 - accuracy: 0.6829
# Epoch 25/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4636 - accuracy: 0.8049
# Epoch 26/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5140 - accuracy: 0.8293
# Epoch 27/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4732 - accuracy: 0.8293
# Epoch 28/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3204 - accuracy: 0.9024
# Epoch 29/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4347 - accuracy: 0.9024
# Epoch 30/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3109 - accuracy: 0.9512
# Epoch 31/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3580 - accuracy: 0.8537
# Epoch 32/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3210 - accuracy: 0.8780
# Epoch 33/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3217 - accuracy: 0.8780
# Epoch 34/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3042 - accuracy: 0.9268
# Epoch 35/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3982 - accuracy: 0.8780
# Epoch 36/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9268
# Epoch 37/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.9512
# Epoch 38/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4100 - accuracy: 0.8537
# Epoch 39/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1840 - accuracy: 0.9512
# Epoch 40/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2608 - accuracy: 0.8537
# Epoch 41/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.9024
# Epoch 42/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3385 - accuracy: 0.9268
# Epoch 43/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3484 - accuracy: 0.9024
# Epoch 44/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 1.0000
# Epoch 45/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1324 - accuracy: 0.9512
# Epoch 46/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2133 - accuracy: 0.9268
# Epoch 47/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.9024
# Epoch 48/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.9756
# Epoch 49/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2852 - accuracy: 0.9024
# Epoch 50/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9756
# Epoch 51/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1754 - accuracy: 0.9756
# Epoch 52/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9024
# Epoch 53/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.9756
# Epoch 54/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3612 - accuracy: 0.8537
# Epoch 55/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1260 - accuracy: 0.9756
# Epoch 56/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3231 - accuracy: 0.9024
# Epoch 57/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2797 - accuracy: 0.9268
# Epoch 58/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.9512
# Epoch 59/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2213 - accuracy: 0.9024
# Epoch 60/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2169 - accuracy: 0.9024
# Epoch 61/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1471 - accuracy: 0.9756
# Epoch 62/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1262 - accuracy: 0.9512
# Epoch 63/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9512
# Epoch 64/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1070 - accuracy: 0.9512
# Epoch 65/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 1.0000
# Epoch 66/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1270 - accuracy: 0.9756
# Epoch 67/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1028 - accuracy: 0.9756
# Epoch 68/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1616 - accuracy: 0.9268
# Epoch 69/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1182 - accuracy: 0.9512
# Epoch 70/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0879 - accuracy: 0.9756
# Epoch 71/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1639 - accuracy: 0.9024
# Epoch 72/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1927 - accuracy: 0.9756
# Epoch 73/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0891 - accuracy: 1.0000
# Epoch 74/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1574 - accuracy: 0.9024
# Epoch 75/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 76/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1115 - accuracy: 0.9512
# Epoch 77/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0647 - accuracy: 1.0000
# Epoch 78/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 79/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9512
# Epoch 80/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9512
# Epoch 81/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9512
# Epoch 82/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2699 - accuracy: 0.9024
# Epoch 83/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1446 - accuracy: 0.9512
# Epoch 84/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1971 - accuracy: 0.8780
# Epoch 85/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1611 - accuracy: 0.9268
# Epoch 86/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2421 - accuracy: 0.8537
# Epoch 87/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2132 - accuracy: 0.9268
# Epoch 88/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3115 - accuracy: 0.9268
# Epoch 89/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1304 - accuracy: 0.9512
# Epoch 90/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1320 - accuracy: 0.9512
# Epoch 91/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1324 - accuracy: 0.9268
# Epoch 92/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0699 - accuracy: 0.9756
# Epoch 93/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1707 - accuracy: 0.9024
# Epoch 94/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1212 - accuracy: 0.9512
# Epoch 95/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1131 - accuracy: 0.9512
# Epoch 96/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9756
# Epoch 97/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1462 - accuracy: 0.9268
# Epoch 98/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9512
# Epoch 99/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3269 - accuracy: 0.8780
# Epoch 100/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1898 - accuracy: 0.9268
# Epoch 101/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0878 - accuracy: 0.9512
# Epoch 102/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0954 - accuracy: 0.9512
# Epoch 103/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1188 - accuracy: 0.9512
# Epoch 104/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1396 - accuracy: 0.9512
# Epoch 105/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1734 - accuracy: 0.9024
# Epoch 106/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1463 - accuracy: 0.9268
# Epoch 107/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.9756
# Epoch 108/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.9512
# Epoch 109/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 110/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.9756
# Epoch 111/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1282 - accuracy: 0.9512
# Epoch 112/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.9268
# Epoch 113/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1412 - accuracy: 0.9512
# Epoch 114/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1669 - accuracy: 0.9268
# Epoch 115/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1195 - accuracy: 0.9756
# Epoch 116/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1823 - accuracy: 0.9268
# Epoch 117/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.8780
# Epoch 118/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1663 - accuracy: 0.9268
# Epoch 119/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1181 - accuracy: 0.9512
# Epoch 121/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1220 - accuracy: 0.9512
# Epoch 122/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1446 - accuracy: 0.9512
# Epoch 123/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1280 - accuracy: 0.9268
# Epoch 124/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0727 - accuracy: 0.9756
# Epoch 125/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0555 - accuracy: 0.9756
# Epoch 126/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0892 - accuracy: 0.9512
# Epoch 127/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9756
# Epoch 128/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0939 - accuracy: 0.9756
# Epoch 129/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0379 - accuracy: 0.9756
# Epoch 130/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0966 - accuracy: 0.9512
# Epoch 131/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 132/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1031 - accuracy: 0.9756
# Epoch 133/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1531 - accuracy: 0.9268
# Epoch 134/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0633 - accuracy: 0.9756
# Epoch 135/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1865 - accuracy: 0.9024
# Epoch 136/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1575 - accuracy: 0.9268
# Epoch 137/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 0.9024
# Epoch 138/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0651 - accuracy: 0.9512
# Epoch 139/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.9756
# Epoch 140/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0994 - accuracy: 0.9756
# Epoch 141/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9512
# Epoch 142/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9512
# Epoch 143/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0537 - accuracy: 0.9756
# Epoch 144/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9512
# Epoch 145/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1959 - accuracy: 0.9268
# Epoch 146/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0650 - accuracy: 0.9756
# Epoch 147/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2724 - accuracy: 0.9512
# Epoch 148/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1350 - accuracy: 0.9512
# Epoch 149/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9756
# Epoch 150/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1526 - accuracy: 0.9512

# %%
#7 Preprocessing the Input

def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) #Contains labels(tags) for highest probability
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# 0
